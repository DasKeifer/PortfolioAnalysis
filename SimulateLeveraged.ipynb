# %%
# %matplotlib inline
import pandas as pd 
import datetime
from pandas_datareader import data as pdr
import yfinance as yfin
yfin.pdr_override()
import AnalysisFunctions

# %%
start = datetime.datetime(2009, 6, 23)
end = datetime.datetime(2019, 1, 1)

df = pdr.get_data_yahoo("SPY", start, end)["Adj Close"]
print (df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2009-06-23 00:00:00-04:00     69.035507
# 2009-06-24 00:00:00-04:00     69.630440
# 2009-06-25 00:00:00-04:00     71.144814
# 2009-06-26 00:00:00-04:00     70.959389
# 2009-06-29 00:00:00-04:00     71.623848
#                                 ...
# 2018-12-24 00:00:00-05:00    219.242188
# 2018-12-26 00:00:00-05:00    230.319321
# 2018-12-27 00:00:00-05:00    232.087570
# 2018-12-28 00:00:00-05:00    231.788177
# 2018-12-31 00:00:00-05:00    233.818359
# Name: Adj Close, Length: 2398, dtype: float64

# %%
start = datetime.datetime(2009, 6, 23)
end = datetime.datetime(2019, 1, 1)

spy = pdr.get_data_yahoo("SPY", start, end)["Adj Close"]
upro = pdr.get_data_yahoo("UPRO", start, end)["Adj Close"]

spy_returns = returns(spy).rename("SPY")
upro_returns = returns(upro).rename("UPRO")

spy_returns.plot(title="Growth of $1: SPY vs UPRO", legend=True, figsize=(10,6))
upro_returns.plot(legend=True)

print("CAGRs")
print(f"SPY: {cagr(spy):.2f}%")
print(f"UPRO: {cagr(upro):.2f}%")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CAGRs
# SPY: 13.67%
# UPRO: 32.63%

# %%
vfinx = pdr.get_data_yahoo("VFINX", start, end)["Adj Close"]
upro_sim = sim_leverage(vfinx, leverage=3.0, expense_ratio=0.0092).rename("UPRO Sim")
upro_sim.plot(title="Growth of $1: UPRO vs UPRO Sim", legend=True, figsize=(10,6))
upro_returns.plot(legend=True);
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
start = datetime.datetime(2010, 2, 9)
end = datetime.datetime(2023, 2, 2)

qqq = pdr.get_data_yahoo("QQQ", start, end)["Adj Close"]
tqqq = pdr.get_data_yahoo("TQQQ", start, end)["Adj Close"]

qqq_returns = returns(qqq).rename("QQQ")
tqqq_returns = returns(tqqq).rename("TQQQ")

qqq_returns.plot(title="Growth of $1: QQQ vs TQQQ", legend=True, figsize=(10,6))
tqqq_returns.plot(legend=True)

print("CAGRs")
print(f"QQQ: {cagr(qqq):.2f}%")
print(f"TQQQ: {cagr(tqqq):.2f}%")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CAGRs
# QQQ: 17.25%
# TQQQ: 36.54%

# %%
tqqq_sim = sim_leverage(qqq, leverage=3.0, expense_ratio=0.0095).rename("TQQQ Sim")
tqqq_sim.plot(title="Growth of $1: TQQQ vs TQQQ Sim", legend=True, figsize=(10,6))
tqqq_returns.plot(legend=True);
