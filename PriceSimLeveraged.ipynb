# %%
# %matplotlib inline

import AnalysisFunctions as af
import SimFunctions as sf

import pandas as pd
import datetime
import math
import os

# %%
spy, spxl = readLeveraged(r'data\prices\pulled\SNP500', 'SPY.csv', 'SPXL.csv')

# %%
spxlSpliced = simulateLeverageHistorical(spy, spxl, 3.2, 0.012)
# Out:
# Splicing together at 2008-11-05
# C:\Users\krjug\AppData\Local\Temp\ipykernel_10504\2375799263.py:14: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leveragedSpliced = simLeveragedEarlier.iloc[:-1].append(leveragedReturns * matchMultiplier)

# %%
spxlSpliced["2008-01-01":"2008-12-31"].plot(legend=True, figsize=(16,6))
# Out:
# <AxesSubplot: >

# %%
af.saveData(spxlSpliced, 'SPXL_Sim', r'data\prices\sim\leveraged\SNP500')

# %%
qqq, tqqq = readLeveraged(r'data\prices\pulled\NASDAQ100', 'QQQ.csv', 'TQQQ.csv')

# %%
tqqqSpliced = simulateLeverageHistorical(qqq, tqqq, 3, 0.0086)
# Out:
# Splicing together at 2010-02-11
# C:\Users\krjug\AppData\Local\Temp\ipykernel_10504\2375799263.py:14: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leveragedSpliced = simLeveragedEarlier.iloc[:-1].append(leveragedReturns * matchMultiplier)

# %%
tqqqSpliced["2010-01-01":"2010-12-31"].plot(legend=True, figsize=(16,6))
# Out:
# <AxesSubplot: >

# %%
af.saveData(tqqqSpliced, 'TQQQ_Sim', r'data\prices\sim\leveraged\NASDAQ100')

# %%
dia, udow = sf.readLeveraged(r'data\prices\pulled\DJIA', 'DIA.csv', 'UDOW.csv')

# %%
udowSpliced = sf.simulateLeverageHistorical(dia, udow, 3, 0.0086)
# Out:
# Splicing together at 2010-02-11
# D:\krjug\Documents\Eplanum\In Progress\stocks\SimFunctions.py:71: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leveragedSpliced = simLeveragedEarlier.iloc[:-1].append(leveragedReturns * matchMultiplier)

# %%
sf.saveData(udowSpliced, 'UDOW_Sim', r'data\prices\sim\leveraged\DJIA')

# %%
iwm, urty = sf.readLeveraged(r'data\prices\pulled\Russell2000', 'IWM.csv', 'URTY.csv')

# %%
urtySpliced = sf.simulateLeverageHistorical(iwm, urty, 3, 0.0095)
# Out:
# Splicing together at 2010-02-11
# D:\krjug\Documents\Eplanum\In Progress\stocks\SimFunctions.py:71: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leveragedSpliced = simLeveragedEarlier.iloc[:-1].append(leveragedReturns * matchMultiplier)

# %%
sf.saveData(urtySpliced, 'URTY_Sim', r'data\prices\sim\leveraged\Russell2000')

# %%
tlt, tmf = readLeveraged(r'data\prices\pulled\Treasury20', 'TLT.csv', 'TMF.csv')

# %%
tmfSpliced = simulateLeverageHistorical(tlt, tmf, 3, 0.01)
# Out:
# Splicing together at 2009-04-16
# C:\Users\krjug\AppData\Local\Temp\ipykernel_10504\2375799263.py:14: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leveragedSpliced = simLeveragedEarlier.iloc[:-1].append(leveragedReturns * matchMultiplier)

# %%
tmfSpliced["2009-01-01":"2009-12-31"].plot(legend=True, figsize=(16,6))
# Out:
# <AxesSubplot: >

# %%
af.saveData(tmfSpliced, 'TMF_Sim', r'data\prices\sim\leveraged\Treasury20')

# %%
ief, tyd = readLeveraged(r'data\prices\pulled\Treasury7-10', 'IEF.csv', 'TYD.csv')

# %%
tydSpliced = simulateLeverageHistorical(ief, tyd, 3, 0.0088)
# Out:
# Splicing together at 2009-04-16
# C:\Users\krjug\AppData\Local\Temp\ipykernel_10504\2375799263.py:14: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leveragedSpliced = simLeveragedEarlier.iloc[:-1].append(leveragedReturns * matchMultiplier)

# %%
tydSpliced["2009-03-01":"2009-05-31"].plot(legend=True, figsize=(16,6))
# Out:
# <AxesSubplot: >

# %%
af.saveData(tydSpliced, 'TYD_Sim', r'data\prices\sim\leveraged\Treasury7-10')

# %%
from importlib import reload
import Utils as utils

reload(sf)
reload(utils)
# Out:
# <module 'Utils' from 'D:\\krjug\\Documents\\Eplanum\\In Progress\\stocks\\Utils.py'>

# %%
idu, utsl = sf.readLeveraged(r'data\prices\pulled\Utils', 'IDU.csv', 'UTSL.csv')

# %%
utslSpliced = sf.simulateLeverageHistorical(idu, utsl, 3, 0.0099)
# Out:
# Splicing together at 2017-05-03
# D:\krjug\Documents\Eplanum\In Progress\stocks\SimFunctions.py:71: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leveragedSpliced = simLeveragedEarlier.iloc[:-1].append(leveragedReturns * matchMultiplier)

# %%
utslSpliced["2017-04-01":"2017-06-31"].plot(legend=True, figsize=(16,6))
# Out:
# <AxesSubplot: >

# %%
sf.saveData(utslSpliced, 'UTSL_Sim', r'data\prices\sim\leveraged\Utils')

# %%
iau, ugl = readLeveraged(r'data\prices\pulled\Gold', 'IAU.csv', 'UGL.csv')

# %%
uglSpliced = simulateLeverageHistorical(iau, ugl, 2, 0.0135)
# Out:
# Splicing together at 2008-12-03
# C:\Users\krjug\AppData\Local\Temp\ipykernel_10504\2375799263.py:14: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leveragedSpliced = simLeveragedEarlier.iloc[:-1].append(leveragedReturns * matchMultiplier)

# %%
uglSpliced["2008-11-01":"2008-12-31"].plot(legend=True, figsize=(16,6))
# Out:
# <AxesSubplot: >

# %%
uglSpliced["2020-11-01":"2025-12-31"].plot(legend=True, figsize=(16,6))
# Out:
# <AxesSubplot: >

# %%
af.saveData(uglSpliced, 'UGL_Sim', r'data\prices\sim\leveraged\Gold')
